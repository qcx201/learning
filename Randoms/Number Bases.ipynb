# %%
default_digits = [str(i) for i in range(10)]
default_digits.extend([chr(i) for i in range(65,127)])

# %%
def validate(base, digits):
    
    # check for digits containing repeating values
    if len(digits) != len(set(digits)):
        raise Exception('Digits contains repeating value')
    else:
        digits = [str(x) for x in digits] # convert digits values to str
    
    # check for valid base
    if type(base)==int:
        if base > len(digits):
            raise Exception(f'Base ({base}) greater than radix (max base {len(digits)})')
            
    elif type(base)==str:
        if base not in digits:
            raise Exception(f'Base "{base}" not in digits')
        else:
            base = digits.index(base) # change base type to int
            
    # check for valid base type
    else:
        raise Exception(f'Base type ({type(base)}) must be int or str')
        
    return base, digits

# %%
def to_10(number, base, digits=None):
    
    if not digits:
        digits = default_digits
        d1 = '1'
    else:
        d1 = str(digits)
    
    base, digits = validate(base, digits)
    
    # special case for base 1
    if base==1:
        return str(number).count(d1)
    
    
    
    bits = str(number)

    for bit in bits:
        if digits.index(bit) >= base:
            raise Exception(f'Number contains invalid bit "{bit}" for base {base}')

    res = 0
    for p, bit in enumerate(reversed(bits)):
        res += (digits.index(bit)*(base**p))

    return res

# %%
def from_10(number, base, digits=None):
    
    number = int(number)
    
    if not digits:
        digits = default_digits
        d1 = '1'
    else:
        d1 = str(digits)
        
    base, digits = validate(base, digits)
    
    # Special case for base 1
    if base==1:
        res = '0' if number==0 else d1 * number
        return int(res) if res.isnumeric() else res
    
    bits = []

    # find highest digit
    p = 0
    while number >= (base**p):
        p += 1
    
    if p==0:
        bits.append(digits[0])
    
    for i in reversed(range(p)):
        bit = number // (base**i)
        number -= (bit * (base**i))
        bits.append(digits[bit])

    res = ''.join(bit for bit in bits)
    
    if all(bit.isnumeric() for bit in bits):
        return int(res)
    else:
        return res

# %%
def base_to_base(number, from_base, to_base, digits=None):
    n10 = to_10(number, from_base, digits)
    return from_10(n10, to_base, digits)

# %%
for i in range(1, 11):
    for num in range(11):
        for j in range(1, 11):
            if i!=1 and any(int(n) >= i for n in str(num)):
                continue
                
            print(f'{num} | base {i} to {j} :', base_to_base(num, i, j))
# Out:
# 0 | base 1 to 1 : 0
# 0 | base 1 to 2 : 0
# 0 | base 1 to 3 : 0
# 0 | base 1 to 4 : 0
# 0 | base 1 to 5 : 0
# 0 | base 1 to 6 : 0
# 0 | base 1 to 7 : 0
# 0 | base 1 to 8 : 0
# 0 | base 1 to 9 : 0
# 0 | base 1 to 10 : 0
# 1 | base 1 to 1 : 1
# 1 | base 1 to 2 : 1
# 1 | base 1 to 3 : 1
# 1 | base 1 to 4 : 1
# 1 | base 1 to 5 : 1
# 1 | base 1 to 6 : 1
# 1 | base 1 to 7 : 1
# 1 | base 1 to 8 : 1
# 1 | base 1 to 9 : 1
# 1 | base 1 to 10 : 1
# 2 | base 1 to 1 : 0
# 2 | base 1 to 2 : 0
# 2 | base 1 to 3 : 0
# 2 | base 1 to 4 : 0
# 2 | base 1 to 5 : 0
# 2 | base 1 to 6 : 0
# 2 | base 1 to 7 : 0
# 2 | base 1 to 8 : 0
# 2 | base 1 to 9 : 0
# 2 | base 1 to 10 : 0
# 3 | base 1 to 1 : 0
# 3 | base 1 to 2 : 0
# 3 | base 1 to 3 : 0
# 3 | base 1 to 4 : 0
# 3 | base 1 to 5 : 0
# 3 | base 1 to 6 : 0
# 3 | base 1 to 7 : 0
# 3 | base 1 to 8 : 0
# 3 | base 1 to 9 : 0
# 3 | base 1 to 10 : 0
# 4 | base 1 to 1 : 0
# 4 | base 1 to 2 : 0
# 4 | base 1 to 3 : 0
# 4 | base 1 to 4 : 0
# 4 | base 1 to 5 : 0
# 4 | base 1 to 6 : 0
# 4 | base 1 to 7 : 0
# 4 | base 1 to 8 : 0
# 4 | base 1 to 9 : 0
# 4 | base 1 to 10 : 0
# 5 | base 1 to 1 : 0
# 5 | base 1 to 2 : 0
# 5 | base 1 to 3 : 0
# 5 | base 1 to 4 : 0
# 5 | base 1 to 5 : 0
# 5 | base 1 to 6 : 0
# 5 | base 1 to 7 : 0
# 5 | base 1 to 8 : 0
# 5 | base 1 to 9 : 0
# 5 | base 1 to 10 : 0
# 6 | base 1 to 1 : 0
# 6 | base 1 to 2 : 0
# 6 | base 1 to 3 : 0
# 6 | base 1 to 4 : 0
# 6 | base 1 to 5 : 0
# 6 | base 1 to 6 : 0
# 6 | base 1 to 7 : 0
# 6 | base 1 to 8 : 0
# 6 | base 1 to 9 : 0
# 6 | base 1 to 10 : 0
# 7 | base 1 to 1 : 0
# 7 | base 1 to 2 : 0
# 7 | base 1 to 3 : 0
# 7 | base 1 to 4 : 0
# 7 | base 1 to 5 : 0
# 7 | base 1 to 6 : 0
# 7 | base 1 to 7 : 0
# 7 | base 1 to 8 : 0
# 7 | base 1 to 9 : 0
# 7 | base 1 to 10 : 0
# 8 | base 1 to 1 : 0
# 8 | base 1 to 2 : 0
# 8 | base 1 to 3 : 0
# 8 | base 1 to 4 : 0
# 8 | base 1 to 5 : 0
# 8 | base 1 to 6 : 0
# 8 | base 1 to 7 : 0
# 8 | base 1 to 8 : 0
# 8 | base 1 to 9 : 0
# 8 | base 1 to 10 : 0
# 9 | base 1 to 1 : 0
# 9 | base 1 to 2 : 0
# 9 | base 1 to 3 : 0
# 9 | base 1 to 4 : 0
# 9 | base 1 to 5 : 0
# 9 | base 1 to 6 : 0
# 9 | base 1 to 7 : 0
# 9 | base 1 to 8 : 0
# 9 | base 1 to 9 : 0
# 9 | base 1 to 10 : 0
# 10 | base 1 to 1 : 1
# 10 | base 1 to 2 : 1
# 10 | base 1 to 3 : 1
# 10 | base 1 to 4 : 1
# 10 | base 1 to 5 : 1
# 10 | base 1 to 6 : 1
# 10 | base 1 to 7 : 1
# 10 | base 1 to 8 : 1
# 10 | base 1 to 9 : 1
# 10 | base 1 to 10 : 1
# 0 | base 2 to 1 : 0
# 0 | base 2 to 2 : 0
# 0 | base 2 to 3 : 0
# 0 | base 2 to 4 : 0
# 0 | base 2 to 5 : 0
# 0 | base 2 to 6 : 0
# 0 | base 2 to 7 : 0
# 0 | base 2 to 8 : 0
# 0 | base 2 to 9 : 0
# 0 | base 2 to 10 : 0
# 1 | base 2 to 1 : 1
# 1 | base 2 to 2 : 1
# 1 | base 2 to 3 : 1
# 1 | base 2 to 4 : 1
# 1 | base 2 to 5 : 1
# 1 | base 2 to 6 : 1
# 1 | base 2 to 7 : 1
# 1 | base 2 to 8 : 1
# 1 | base 2 to 9 : 1
# 1 | base 2 to 10 : 1
# 10 | base 2 to 1 : 11
# 10 | base 2 to 2 : 10
# 10 | base 2 to 3 : 2
# 10 | base 2 to 4 : 2
# 10 | base 2 to 5 : 2
# 10 | base 2 to 6 : 2
# 10 | base 2 to 7 : 2
# 10 | base 2 to 8 : 2
# 10 | base 2 to 9 : 2
# 10 | base 2 to 10 : 2
# 0 | base 3 to 1 : 0
# 0 | base 3 to 2 : 0
# 0 | base 3 to 3 : 0
# 0 | base 3 to 4 : 0
# 0 | base 3 to 5 : 0
# 0 | base 3 to 6 : 0
# 0 | base 3 to 7 : 0
# 0 | base 3 to 8 : 0
# 0 | base 3 to 9 : 0
# 0 | base 3 to 10 : 0
# 1 | base 3 to 1 : 1
# 1 | base 3 to 2 : 1
# 1 | base 3 to 3 : 1
# 1 | base 3 to 4 : 1
# 1 | base 3 to 5 : 1
# 1 | base 3 to 6 : 1
# 1 | base 3 to 7 : 1
# 1 | base 3 to 8 : 1
# 1 | base 3 to 9 : 1
# 1 | base 3 to 10 : 1
# 2 | base 3 to 1 : 11
# 2 | base 3 to 2 : 10
# 2 | base 3 to 3 : 2
# 2 | base 3 to 4 : 2
# 2 | base 3 to 5 : 2
# 2 | base 3 to 6 : 2
# 2 | base 3 to 7 : 2
# 2 | base 3 to 8 : 2
# 2 | base 3 to 9 : 2
# 2 | base 3 to 10 : 2
# 10 | base 3 to 1 : 111
# 10 | base 3 to 2 : 11
# 10 | base 3 to 3 : 10
# 10 | base 3 to 4 : 3
# 10 | base 3 to 5 : 3
# 10 | base 3 to 6 : 3
# 10 | base 3 to 7 : 3
# 10 | base 3 to 8 : 3
# 10 | base 3 to 9 : 3
# 10 | base 3 to 10 : 3
# 0 | base 4 to 1 : 0
# 0 | base 4 to 2 : 0
# 0 | base 4 to 3 : 0
# 0 | base 4 to 4 : 0
# 0 | base 4 to 5 : 0
# 0 | base 4 to 6 : 0
# 0 | base 4 to 7 : 0
# 0 | base 4 to 8 : 0
# 0 | base 4 to 9 : 0
# 0 | base 4 to 10 : 0
# 1 | base 4 to 1 : 1
# 1 | base 4 to 2 : 1
# 1 | base 4 to 3 : 1
# 1 | base 4 to 4 : 1
# 1 | base 4 to 5 : 1
# 1 | base 4 to 6 : 1
# 1 | base 4 to 7 : 1
# 1 | base 4 to 8 : 1
# 1 | base 4 to 9 : 1
# 1 | base 4 to 10 : 1
# 2 | base 4 to 1 : 11
# 2 | base 4 to 2 : 10
# 2 | base 4 to 3 : 2
# 2 | base 4 to 4 : 2
# 2 | base 4 to 5 : 2
# 2 | base 4 to 6 : 2
# 2 | base 4 to 7 : 2
# 2 | base 4 to 8 : 2
# 2 | base 4 to 9 : 2
# 2 | base 4 to 10 : 2
# 3 | base 4 to 1 : 111
# 3 | base 4 to 2 : 11
# 3 | base 4 to 3 : 10
# 3 | base 4 to 4 : 3
# 3 | base 4 to 5 : 3
# 3 | base 4 to 6 : 3
# 3 | base 4 to 7 : 3
# 3 | base 4 to 8 : 3
# 3 | base 4 to 9 : 3
# 3 | base 4 to 10 : 3
# 10 | base 4 to 1 : 1111
# 10 | base 4 to 2 : 100
# 10 | base 4 to 3 : 11
# 10 | base 4 to 4 : 10
# 10 | base 4 to 5 : 4
# 10 | base 4 to 6 : 4
# 10 | base 4 to 7 : 4
# 10 | base 4 to 8 : 4
# 10 | base 4 to 9 : 4
# 10 | base 4 to 10 : 4
# 0 | base 5 to 1 : 0
# 0 | base 5 to 2 : 0
# 0 | base 5 to 3 : 0
# 0 | base 5 to 4 : 0
# 0 | base 5 to 5 : 0
# 0 | base 5 to 6 : 0
# 0 | base 5 to 7 : 0
# 0 | base 5 to 8 : 0
# 0 | base 5 to 9 : 0
# 0 | base 5 to 10 : 0
# 1 | base 5 to 1 : 1
# 1 | base 5 to 2 : 1
# 1 | base 5 to 3 : 1
# 1 | base 5 to 4 : 1
# 1 | base 5 to 5 : 1
# 1 | base 5 to 6 : 1
# 1 | base 5 to 7 : 1
# 1 | base 5 to 8 : 1
# 1 | base 5 to 9 : 1
# 1 | base 5 to 10 : 1
# 2 | base 5 to 1 : 11
# 2 | base 5 to 2 : 10
# 2 | base 5 to 3 : 2
# 2 | base 5 to 4 : 2
# 2 | base 5 to 5 : 2
# 2 | base 5 to 6 : 2
# 2 | base 5 to 7 : 2
# 2 | base 5 to 8 : 2
# 2 | base 5 to 9 : 2
# 2 | base 5 to 10 : 2
# 3 | base 5 to 1 : 111
# 3 | base 5 to 2 : 11
# 3 | base 5 to 3 : 10
# 3 | base 5 to 4 : 3
# 3 | base 5 to 5 : 3
# 3 | base 5 to 6 : 3
# 3 | base 5 to 7 : 3
# 3 | base 5 to 8 : 3
# 3 | base 5 to 9 : 3
# 3 | base 5 to 10 : 3
# 4 | base 5 to 1 : 1111
# 4 | base 5 to 2 : 100
# 4 | base 5 to 3 : 11
# 4 | base 5 to 4 : 10
# 4 | base 5 to 5 : 4
# 4 | base 5 to 6 : 4
# 4 | base 5 to 7 : 4
# 4 | base 5 to 8 : 4
# 4 | base 5 to 9 : 4
# 4 | base 5 to 10 : 4
# 10 | base 5 to 1 : 11111
# 10 | base 5 to 2 : 101
# 10 | base 5 to 3 : 12
# 10 | base 5 to 4 : 11
# 10 | base 5 to 5 : 10
# 10 | base 5 to 6 : 5
# 10 | base 5 to 7 : 5
# 10 | base 5 to 8 : 5
# 10 | base 5 to 9 : 5
# 10 | base 5 to 10 : 5
# 0 | base 6 to 1 : 0
# 0 | base 6 to 2 : 0
# 0 | base 6 to 3 : 0
# 0 | base 6 to 4 : 0
# 0 | base 6 to 5 : 0
# 0 | base 6 to 6 : 0
# 0 | base 6 to 7 : 0
# 0 | base 6 to 8 : 0
# 0 | base 6 to 9 : 0
# 0 | base 6 to 10 : 0
# 1 | base 6 to 1 : 1
# 1 | base 6 to 2 : 1
# 1 | base 6 to 3 : 1
# 1 | base 6 to 4 : 1
# 1 | base 6 to 5 : 1
# 1 | base 6 to 6 : 1
# 1 | base 6 to 7 : 1
# 1 | base 6 to 8 : 1
# 1 | base 6 to 9 : 1
# 1 | base 6 to 10 : 1
# 2 | base 6 to 1 : 11
# 2 | base 6 to 2 : 10
# 2 | base 6 to 3 : 2
# 2 | base 6 to 4 : 2
# 2 | base 6 to 5 : 2
# 2 | base 6 to 6 : 2
# 2 | base 6 to 7 : 2
# 2 | base 6 to 8 : 2
# 2 | base 6 to 9 : 2
# 2 | base 6 to 10 : 2
# 3 | base 6 to 1 : 111
# 3 | base 6 to 2 : 11
# 3 | base 6 to 3 : 10
# 3 | base 6 to 4 : 3
# 3 | base 6 to 5 : 3
# 3 | base 6 to 6 : 3
# 3 | base 6 to 7 : 3
# 3 | base 6 to 8 : 3
# 3 | base 6 to 9 : 3
# 3 | base 6 to 10 : 3
# 4 | base 6 to 1 : 1111
# 4 | base 6 to 2 : 100
# 4 | base 6 to 3 : 11
# 4 | base 6 to 4 : 10
# 4 | base 6 to 5 : 4
# 4 | base 6 to 6 : 4
# 4 | base 6 to 7 : 4
# 4 | base 6 to 8 : 4
# 4 | base 6 to 9 : 4
# 4 | base 6 to 10 : 4
# 5 | base 6 to 1 : 11111
# 5 | base 6 to 2 : 101
# 5 | base 6 to 3 : 12
# 5 | base 6 to 4 : 11
# 5 | base 6 to 5 : 10
# 5 | base 6 to 6 : 5
# 5 | base 6 to 7 : 5
# 5 | base 6 to 8 : 5
# 5 | base 6 to 9 : 5
# 5 | base 6 to 10 : 5
# 10 | base 6 to 1 : 111111
# 10 | base 6 to 2 : 110
# 10 | base 6 to 3 : 20
# 10 | base 6 to 4 : 12
# 10 | base 6 to 5 : 11
# 10 | base 6 to 6 : 10
# 10 | base 6 to 7 : 6
# 10 | base 6 to 8 : 6
# 10 | base 6 to 9 : 6
# 10 | base 6 to 10 : 6
# 0 | base 7 to 1 : 0
# 0 | base 7 to 2 : 0
# 0 | base 7 to 3 : 0
# 0 | base 7 to 4 : 0
# 0 | base 7 to 5 : 0
# 0 | base 7 to 6 : 0
# 0 | base 7 to 7 : 0
# 0 | base 7 to 8 : 0
# 0 | base 7 to 9 : 0
# 0 | base 7 to 10 : 0
# 1 | base 7 to 1 : 1
# 1 | base 7 to 2 : 1
# 1 | base 7 to 3 : 1
# 1 | base 7 to 4 : 1
# 1 | base 7 to 5 : 1
# 1 | base 7 to 6 : 1
# 1 | base 7 to 7 : 1
# 1 | base 7 to 8 : 1
# 1 | base 7 to 9 : 1
# 1 | base 7 to 10 : 1
# 2 | base 7 to 1 : 11
# 2 | base 7 to 2 : 10
# 2 | base 7 to 3 : 2
# 2 | base 7 to 4 : 2
# 2 | base 7 to 5 : 2
# 2 | base 7 to 6 : 2
# 2 | base 7 to 7 : 2
# 2 | base 7 to 8 : 2
# 2 | base 7 to 9 : 2
# 2 | base 7 to 10 : 2
# 3 | base 7 to 1 : 111
# 3 | base 7 to 2 : 11
# 3 | base 7 to 3 : 10
# 3 | base 7 to 4 : 3
# 3 | base 7 to 5 : 3
# 3 | base 7 to 6 : 3
# 3 | base 7 to 7 : 3
# 3 | base 7 to 8 : 3
# 3 | base 7 to 9 : 3
# 3 | base 7 to 10 : 3
# 4 | base 7 to 1 : 1111
# 4 | base 7 to 2 : 100
# 4 | base 7 to 3 : 11
# 4 | base 7 to 4 : 10
# 4 | base 7 to 5 : 4
# 4 | base 7 to 6 : 4
# 4 | base 7 to 7 : 4
# 4 | base 7 to 8 : 4
# 4 | base 7 to 9 : 4
# 4 | base 7 to 10 : 4
# 5 | base 7 to 1 : 11111
# 5 | base 7 to 2 : 101
# 5 | base 7 to 3 : 12
# 5 | base 7 to 4 : 11
# 5 | base 7 to 5 : 10
# 5 | base 7 to 6 : 5
# 5 | base 7 to 7 : 5
# 5 | base 7 to 8 : 5
# 5 | base 7 to 9 : 5
# 5 | base 7 to 10 : 5
# 6 | base 7 to 1 : 111111
# 6 | base 7 to 2 : 110
# 6 | base 7 to 3 : 20
# 6 | base 7 to 4 : 12
# 6 | base 7 to 5 : 11
# 6 | base 7 to 6 : 10
# 6 | base 7 to 7 : 6
# 6 | base 7 to 8 : 6
# 6 | base 7 to 9 : 6
# 6 | base 7 to 10 : 6
# 10 | base 7 to 1 : 1111111
# 10 | base 7 to 2 : 111
# 10 | base 7 to 3 : 21
# 10 | base 7 to 4 : 13
# 10 | base 7 to 5 : 12
# 10 | base 7 to 6 : 11
# 10 | base 7 to 7 : 10
# 10 | base 7 to 8 : 7
# 10 | base 7 to 9 : 7
# 10 | base 7 to 10 : 7
# 0 | base 8 to 1 : 0
# 0 | base 8 to 2 : 0
# 0 | base 8 to 3 : 0
# 0 | base 8 to 4 : 0
# 0 | base 8 to 5 : 0
# 0 | base 8 to 6 : 0
# 0 | base 8 to 7 : 0
# 0 | base 8 to 8 : 0
# 0 | base 8 to 9 : 0
# 0 | base 8 to 10 : 0
# 1 | base 8 to 1 : 1
# 1 | base 8 to 2 : 1
# 1 | base 8 to 3 : 1
# 1 | base 8 to 4 : 1
# 1 | base 8 to 5 : 1
# 1 | base 8 to 6 : 1
# 1 | base 8 to 7 : 1
# 1 | base 8 to 8 : 1
# 1 | base 8 to 9 : 1
# 1 | base 8 to 10 : 1
# 2 | base 8 to 1 : 11
# 2 | base 8 to 2 : 10
# 2 | base 8 to 3 : 2
# 2 | base 8 to 4 : 2
# 2 | base 8 to 5 : 2
# 2 | base 8 to 6 : 2
# 2 | base 8 to 7 : 2
# 2 | base 8 to 8 : 2
# 2 | base 8 to 9 : 2
# 2 | base 8 to 10 : 2
# 3 | base 8 to 1 : 111
# 3 | base 8 to 2 : 11
# 3 | base 8 to 3 : 10
# 3 | base 8 to 4 : 3
# 3 | base 8 to 5 : 3
# 3 | base 8 to 6 : 3
# 3 | base 8 to 7 : 3
# 3 | base 8 to 8 : 3
# 3 | base 8 to 9 : 3
# 3 | base 8 to 10 : 3
# 4 | base 8 to 1 : 1111
# 4 | base 8 to 2 : 100
# 4 | base 8 to 3 : 11
# 4 | base 8 to 4 : 10
# 4 | base 8 to 5 : 4
# 4 | base 8 to 6 : 4
# 4 | base 8 to 7 : 4
# 4 | base 8 to 8 : 4
# 4 | base 8 to 9 : 4
# 4 | base 8 to 10 : 4
# 5 | base 8 to 1 : 11111
# 5 | base 8 to 2 : 101
# 5 | base 8 to 3 : 12
# 5 | base 8 to 4 : 11
# 5 | base 8 to 5 : 10
# 5 | base 8 to 6 : 5
# 5 | base 8 to 7 : 5
# 5 | base 8 to 8 : 5
# 5 | base 8 to 9 : 5
# 5 | base 8 to 10 : 5
# 6 | base 8 to 1 : 111111
# 6 | base 8 to 2 : 110
# 6 | base 8 to 3 : 20
# 6 | base 8 to 4 : 12
# 6 | base 8 to 5 : 11
# 6 | base 8 to 6 : 10
# 6 | base 8 to 7 : 6
# 6 | base 8 to 8 : 6
# 6 | base 8 to 9 : 6
# 6 | base 8 to 10 : 6
# 7 | base 8 to 1 : 1111111
# 7 | base 8 to 2 : 111
# 7 | base 8 to 3 : 21
# 7 | base 8 to 4 : 13
# 7 | base 8 to 5 : 12
# 7 | base 8 to 6 : 11
# 7 | base 8 to 7 : 10
# 7 | base 8 to 8 : 7
# 7 | base 8 to 9 : 7
# 7 | base 8 to 10 : 7
# 10 | base 8 to 1 : 11111111
# 10 | base 8 to 2 : 1000
# 10 | base 8 to 3 : 22
# 10 | base 8 to 4 : 20
# 10 | base 8 to 5 : 13
# 10 | base 8 to 6 : 12
# 10 | base 8 to 7 : 11
# 10 | base 8 to 8 : 10
# 10 | base 8 to 9 : 8
# 10 | base 8 to 10 : 8
# 0 | base 9 to 1 : 0
# 0 | base 9 to 2 : 0
# 0 | base 9 to 3 : 0
# 0 | base 9 to 4 : 0
# 0 | base 9 to 5 : 0
# 0 | base 9 to 6 : 0
# 0 | base 9 to 7 : 0
# 0 | base 9 to 8 : 0
# 0 | base 9 to 9 : 0
# 0 | base 9 to 10 : 0
# 1 | base 9 to 1 : 1
# 1 | base 9 to 2 : 1
# 1 | base 9 to 3 : 1
# 1 | base 9 to 4 : 1
# 1 | base 9 to 5 : 1
# 1 | base 9 to 6 : 1
# 1 | base 9 to 7 : 1
# 1 | base 9 to 8 : 1
# 1 | base 9 to 9 : 1
# 1 | base 9 to 10 : 1
# 2 | base 9 to 1 : 11
# 2 | base 9 to 2 : 10
# 2 | base 9 to 3 : 2
# 2 | base 9 to 4 : 2
# 2 | base 9 to 5 : 2
# 2 | base 9 to 6 : 2
# 2 | base 9 to 7 : 2
# 2 | base 9 to 8 : 2
# 2 | base 9 to 9 : 2
# 2 | base 9 to 10 : 2
# 3 | base 9 to 1 : 111
# 3 | base 9 to 2 : 11
# 3 | base 9 to 3 : 10
# 3 | base 9 to 4 : 3
# 3 | base 9 to 5 : 3
# 3 | base 9 to 6 : 3
# 3 | base 9 to 7 : 3
# 3 | base 9 to 8 : 3
# 3 | base 9 to 9 : 3
# 3 | base 9 to 10 : 3
# 4 | base 9 to 1 : 1111
# 4 | base 9 to 2 : 100
# 4 | base 9 to 3 : 11
# 4 | base 9 to 4 : 10
# 4 | base 9 to 5 : 4
# 4 | base 9 to 6 : 4
# 4 | base 9 to 7 : 4
# 4 | base 9 to 8 : 4
# 4 | base 9 to 9 : 4
# 4 | base 9 to 10 : 4
# 5 | base 9 to 1 : 11111
# 5 | base 9 to 2 : 101
# 5 | base 9 to 3 : 12
# 5 | base 9 to 4 : 11
# 5 | base 9 to 5 : 10
# 5 | base 9 to 6 : 5
# 5 | base 9 to 7 : 5
# 5 | base 9 to 8 : 5
# 5 | base 9 to 9 : 5
# 5 | base 9 to 10 : 5
# 6 | base 9 to 1 : 111111
# 6 | base 9 to 2 : 110
# 6 | base 9 to 3 : 20
# 6 | base 9 to 4 : 12
# 6 | base 9 to 5 : 11
# 6 | base 9 to 6 : 10
# 6 | base 9 to 7 : 6
# 6 | base 9 to 8 : 6
# 6 | base 9 to 9 : 6
# 6 | base 9 to 10 : 6
# 7 | base 9 to 1 : 1111111
# 7 | base 9 to 2 : 111
# 7 | base 9 to 3 : 21
# 7 | base 9 to 4 : 13
# 7 | base 9 to 5 : 12
# 7 | base 9 to 6 : 11
# 7 | base 9 to 7 : 10
# 7 | base 9 to 8 : 7
# 7 | base 9 to 9 : 7
# 7 | base 9 to 10 : 7
# 8 | base 9 to 1 : 11111111
# 8 | base 9 to 2 : 1000
# 8 | base 9 to 3 : 22
# 8 | base 9 to 4 : 20
# 8 | base 9 to 5 : 13
# 8 | base 9 to 6 : 12
# 8 | base 9 to 7 : 11
# 8 | base 9 to 8 : 10
# 8 | base 9 to 9 : 8
# 8 | base 9 to 10 : 8
# 10 | base 9 to 1 : 111111111
# 10 | base 9 to 2 : 1001
# 10 | base 9 to 3 : 100
# 10 | base 9 to 4 : 21
# 10 | base 9 to 5 : 14
# 10 | base 9 to 6 : 13
# 10 | base 9 to 7 : 12
# 10 | base 9 to 8 : 11
# 10 | base 9 to 9 : 10
# 10 | base 9 to 10 : 9
# 0 | base 10 to 1 : 0
# 0 | base 10 to 2 : 0
# 0 | base 10 to 3 : 0
# 0 | base 10 to 4 : 0
# 0 | base 10 to 5 : 0
# 0 | base 10 to 6 : 0
# 0 | base 10 to 7 : 0
# 0 | base 10 to 8 : 0
# 0 | base 10 to 9 : 0
# 0 | base 10 to 10 : 0
# 1 | base 10 to 1 : 1
# 1 | base 10 to 2 : 1
# 1 | base 10 to 3 : 1
# 1 | base 10 to 4 : 1
# 1 | base 10 to 5 : 1
# 1 | base 10 to 6 : 1
# 1 | base 10 to 7 : 1
# 1 | base 10 to 8 : 1
# 1 | base 10 to 9 : 1
# 1 | base 10 to 10 : 1
# 2 | base 10 to 1 : 11
# 2 | base 10 to 2 : 10
# 2 | base 10 to 3 : 2
# 2 | base 10 to 4 : 2
# 2 | base 10 to 5 : 2
# 2 | base 10 to 6 : 2
# 2 | base 10 to 7 : 2
# 2 | base 10 to 8 : 2
# 2 | base 10 to 9 : 2
# 2 | base 10 to 10 : 2
# 3 | base 10 to 1 : 111
# 3 | base 10 to 2 : 11
# 3 | base 10 to 3 : 10
# 3 | base 10 to 4 : 3
# 3 | base 10 to 5 : 3
# 3 | base 10 to 6 : 3
# 3 | base 10 to 7 : 3
# 3 | base 10 to 8 : 3
# 3 | base 10 to 9 : 3
# 3 | base 10 to 10 : 3
# 4 | base 10 to 1 : 1111
# 4 | base 10 to 2 : 100
# 4 | base 10 to 3 : 11
# 4 | base 10 to 4 : 10
# 4 | base 10 to 5 : 4
# 4 | base 10 to 6 : 4
# 4 | base 10 to 7 : 4
# 4 | base 10 to 8 : 4
# 4 | base 10 to 9 : 4
# 4 | base 10 to 10 : 4
# 5 | base 10 to 1 : 11111
# 5 | base 10 to 2 : 101
# 5 | base 10 to 3 : 12
# 5 | base 10 to 4 : 11
# 5 | base 10 to 5 : 10
# 5 | base 10 to 6 : 5
# 5 | base 10 to 7 : 5
# 5 | base 10 to 8 : 5
# 5 | base 10 to 9 : 5
# 5 | base 10 to 10 : 5
# 6 | base 10 to 1 : 111111
# 6 | base 10 to 2 : 110
# 6 | base 10 to 3 : 20
# 6 | base 10 to 4 : 12
# 6 | base 10 to 5 : 11
# 6 | base 10 to 6 : 10
# 6 | base 10 to 7 : 6
# 6 | base 10 to 8 : 6
# 6 | base 10 to 9 : 6
# 6 | base 10 to 10 : 6
# 7 | base 10 to 1 : 1111111
# 7 | base 10 to 2 : 111
# 7 | base 10 to 3 : 21
# 7 | base 10 to 4 : 13
# 7 | base 10 to 5 : 12
# 7 | base 10 to 6 : 11
# 7 | base 10 to 7 : 10
# 7 | base 10 to 8 : 7
# 7 | base 10 to 9 : 7
# 7 | base 10 to 10 : 7
# 8 | base 10 to 1 : 11111111
# 8 | base 10 to 2 : 1000
# 8 | base 10 to 3 : 22
# 8 | base 10 to 4 : 20
# 8 | base 10 to 5 : 13
# 8 | base 10 to 6 : 12
# 8 | base 10 to 7 : 11
# 8 | base 10 to 8 : 10
# 8 | base 10 to 9 : 8
# 8 | base 10 to 10 : 8
# 9 | base 10 to 1 : 111111111
# 9 | base 10 to 2 : 1001
# 9 | base 10 to 3 : 100
# 9 | base 10 to 4 : 21
# 9 | base 10 to 5 : 14
# 9 | base 10 to 6 : 13
# 9 | base 10 to 7 : 12
# 9 | base 10 to 8 : 11
# 9 | base 10 to 9 : 10
# 9 | base 10 to 10 : 9
# 10 | base 10 to 1 : 1111111111
# 10 | base 10 to 2 : 1010
# 10 | base 10 to 3 : 101
# 10 | base 10 to 4 : 22
# 10 | base 10 to 5 : 20
# 10 | base 10 to 6 : 14
# 10 | base 10 to 7 : 13
# 10 | base 10 to 8 : 12
# 10 | base 10 to 9 : 11
# 10 | base 10 to 10 : 10
