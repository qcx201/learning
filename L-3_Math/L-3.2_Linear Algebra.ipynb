# %% [markdown]
# # Linear Algebra 🔠🧮
# ---
#
# <center><img src="https://media.giphy.com/media/eIm624c8nnNbiG0V3g/giphy.gif"><\center>

# %% [markdown]
# <a id=contents></a>
#
#
# # Contents
# ---
#
#
# ### Chapter 1: Systems of Equations
#
# * Gaussian elimination
#
#
#
# ### Chapter 2: Vectors
#
# * Scalars, addition, and broadcasting
#
# * Dot product
#
# * Distributivity and transpose
#
#
# ### Section 3: Matrices
#
# * Matrix operations
#
# * Identity and inverse matrix
#
# * Eigen decomposition
#
#
# ### Section 4: Vector Calculus
#
#
#
# ---
#
# Materials primarily based on [**Paul's Online Notes**](https://tutorial.math.lamar.edu/Classes/CalcI/CalcI.aspx) for Calculus I.

# %%
import numpy as np
import sympy as sp

import matplotlib.pyplot as plt
# %matplotlib inline

# !curl https://raw.githubusercontent.com/websitenotavailable/learning/master/L-3_lx/learnmath.py -o ./learnmath.py
from learnmath import *

# %%
a, b, c, d = sp.symbols('a, b, c, d')
y = np.array([a, b])
x = sp.Matrix([a, b])

# %% [markdown]
# # Chapter 1: Systems of Equations

# %%
# systems of equations

# %% [markdown]
# # Chapter 2: Vectors

# %%
textbu('Vectors', tag='h1')

vspace()

a, b, c, d = sp.symbols('a, b, c, d')

# a column vector
v1 = sp.Matrix([a, b])

# a row vector
v2 = sp.Matrix([a, b]).T # transpose

# a column vector
v3 = sp.Matrix([c, d])

# show
for i, v in enumerate([v1, v2, v3]):
    
    tbu(f'Vector {i}:')
    
    Lx(v).show()
    
    md('shape (rows, columns):', v.shape)
# Out:
# <h1 style="color:">Vectors</h1>
# <span style="display:block; height:8px;"></span>
# <b style="color:"><u>Vector 0:</u></b>
# $$\begin{align*} \quad \left[\begin{matrix}a\\b\end{matrix}\right]\\\\ \end{align*}$$
# shape (rows, columns):
# (2, 1)
# <b style="color:"><u>Vector 1:</u></b>
# $$\begin{align*} \quad \left[\begin{matrix}a & b\end{matrix}\right]\\\\ \end{align*}$$
# shape (rows, columns):
# (1, 2)
# <b style="color:"><u>Vector 2:</u></b>
# $$\begin{align*} \quad \left[\begin{matrix}c\\d\end{matrix}\right]\\\\ \end{align*}$$
# shape (rows, columns):
# (2, 1)

# %% [markdown]
# ## Plot Vectors

# %%
# origin (zero vector)
v0 = np.array([0, 0])

# first vector
v1 = np.array([0, 1])

# second vector
v2 = np.array([1, 0])


# (label, origin, vector) triples
OGV = [
    # add v2 to v1
    (v0, v1, '$v_1$'),
    (v1, v2, '$v_2$'),
    # add vectors
    (v0, v1 + v2, '$v_1 + v_2$'),
]

fig, ax, plots = plot_vectors(*transpose(OGV))
plt.show()

# show vector latex
Lx(r'\quad').join(
    Lx('v_1', v1),
    Lx('v_2',  v2),
    Lx('v_1 + v_2', v1+v2)
).show(center=False)
# Out:
# $\displaystyle \begin{align*} \quad  v_1 = \begin{bmatrix}0\\1\end{bmatrix} \quad v_2 = \begin{bmatrix}1\\0\end{bmatrix} \quad v_1 + v_2 = \begin{bmatrix}1\\1\end{bmatrix} \\\\ \end{align*}$

# %%
fig, ax = plt.subplots(figsize=(8, 8))

ax.quiver(0, 0, 1, 1,
          scale=1,
          width=0.0125,
          angles='xy',
          color=dcolors[0],
          scale_units='xy')

ax.quiver(1, 1, -1, 1,
          scale=1,
          width=0.0125,
          angles='xy',
          color=dcolors[1],
          scale_units='xy')

ax.set_xlim(-0.1, 3)
ax.set_ylim(-0.1, 3)

ax.grid()

plt.show()

# %%
# %matplotlib notebook

# 3-D plot
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection='3d')

fmt = dict(arrow_length_ratio=0.15, lw=3)

ax.quiver(0, 0, 0,
          1, 1, 1,
          **fmt
         )

ax.quiver(1, 1, 1,
          1, 1, -1,
          **fmt
         )

ax.set_title('3-D Vector')

ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
ax.set_zlim(0, 3)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
# Out:
# <img src="data:image/png;base64,..." width="576">
